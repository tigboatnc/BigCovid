# %%
import pandas as pd
import numpy as np

# %%
nhspi = pd.read_csv('../data/nhspi_2021_domains.csv')

# %% [markdown]
# # Converting dataset to year-wise chunks

# %%
nhspi_year = []

for year in range (2013,2021):
    nhspi_year.append(nhspi[nhspi['YEAR']==year])

# %%
for frame,year in zip(nhspi_year,range (2013,2021)):
    frame.rename({'HSS': f'HSS_{year}',
              'CPE': f'CPE_{year}',
              'IIM': f'IIM_{year}',
              'HD': f'HD_{year}',
              'CM': f'CM_{year}',
              'EOH': f'EOH_{year}'}, axis=1, inplace=True)
    frame.drop(['YEAR'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)
# /tmp/ipykernel_783/1665288106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.rename({'HSS': f'HSS_{year}',
# /tmp/ipykernel_783/1665288106.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame.drop(['YEAR'],axis=1,inplace=True)

# %%
main_data = nhspi_year[0]

for target in nhspi_year[1:]:
    
    main_data = pd.merge(main_data, target, on='STATE')

# %%
main_data.to_csv('../data/nhspi_2021_domains_processed.csv')

# %% [markdown]
# # Checking Correlation with case peak data

# %%
case_peak = pd.read_csv('../data/state_peak.csv')

# %%
case_peak
# Out:
#     Unnamed: 0 state                                         peak_dates  \
# 0            0    UT  ['2020-11-19', '2021-01-05', '2021-11-05', '20...
# 1            1    CO  ['2020-11-22', '2021-11-08', '2021-09-07', '20...
# 2            2    AR  ['2021-01-06', '2021-08-13', '2020-07-26', '20...
# 3            3    AS                                                 []
# 4            4    HI  ['2021-08-28', '2020-08-22', '2021-01-08', '20...
# 5            5    AK  ['2021-09-27', '2020-11-29', '2021-04-05', '20...
# 43          43    VI  ['2021-08-10', '2020-08-18', '2020-12-11', '20...
# 44          44    NH  ['2021-01-07', '2020-12-14', '2021-11-16', '20...
# 45          45    MD  ['2021-01-07', '2020-12-09', '2021-04-07', '20...
# 46          46    WA  ['2021-09-02', '2020-12-07', '2021-01-06', '20...
# 47          47    MT  ['2020-11-17', '2021-10-03', '2021-01-06', '20...
# 48          48    LA  ['2021-08-11', '2021-01-08', '2020-07-20', '20...
# 49          49    DC  ['2021-01-10', '2020-12-12', '2021-09-15', '20...
# 50          50    NJ  ['2021-01-11', '2020-12-09', '2021-03-27', '20...
# 51          51    KY  ['2021-09-02', '2021-01-10', '2020-12-03', '20...
# 52          52    WY  ['2020-11-17', '2021-09-14', '2021-01-09', '20...
# 53          53    MN  ['2020-11-20', '2021-11-18', '2021-10-07', '20...
# 54          54   FSM                                                 []
# 55          55    AZ  ['2021-01-08', '2020-07-05', '2021-08-27', '20...
# 56          56    RI  ['2020-12-06', '2021-01-04', '2021-04-03', '20...
# 57          57    SC  ['2021-09-02', '2021-01-10', '2020-07-16', '20...
# 58          58    VA  ['2021-01-14', '2021-09-10', '2021-04-02', '20...
# 59          59    OR  ['2021-08-27', '2020-12-04', '2021-01-03', '20...
#
#                                       peak_properties
# 0             [610.0, 2943.0, 2682.0, 1478.0, 1527.0]
# 1      [463.0, 521.0, 4930.0, 1617.0, 1788.0, 2911.0]
# 2               [101.0, 746.0, 2572.0, 194.0, 2186.0]
# 3                                                  []
# 4            [19.0, 224.0, 89.0, 145.0, 103.0, 757.0]
# 5                   [10.0, 85.0, 620.0, 163.0, 972.0]
# 6          [8670.0, 4921.0, 20499.0, 1600.0, 16901.0]
# 7       [100.0, 785.0, 3091.0, 3467.0, 2506.0, 694.0]
# 8             [712.0, 3692.0, 8452.0, 1379.0, 8372.0]
# 9                    [1994.0, 5411.0, 2090.0, 1766.0]
# 10                                              [1.0]
# 11    [26.0, 17.0, 319.0, 344.0, 791.0, 870.0, 781.0]
# 12  [231.0, 434.0, 547.0, 2545.0, 2057.0, 232.0, 1...
# 13         [929.0, 10325.0, 13423.0, 5824.0, 20956.0]
# 14                                                 []
# 15         [34.0, 31.0, 125.0, 1339.0, 390.0, 1721.0]
# 16    [4674.0, 354.0, 5712.0, 3914.0, 1913.0, 1733.0]
# 17  [148.0, 137.0, 278.0, 1984.0, 210.0, 784.0, 12...
# 18            [1423.0, 878.0, 9305.0, 4375.0, 4689.0]
# 19  [434.0, 503.0, 843.0, 3686.0, 1402.0, 516.0, 1...
# 20            [385.0, 2084.0, 7467.0, 1247.0, 7224.0]
# 21    [614.0, 1293.0, 1065.0, 9837.0, 1932.0, 6489.0]
